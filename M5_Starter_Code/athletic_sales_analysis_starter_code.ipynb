# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
sales_2020_df = pd.read_csv('Resources/athletic_sales_2020.csv')
sales_2021_df = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
sales_2020_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
sales_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
sales_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
sales_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combined_df = pd.concat([sales_2020_df, sales_2021_df], axis='rows', join='inner').reset_index(drop=True)
combined_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
combined_df.isnull().sum()
# Out:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
# Check the data type of each column
combined_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
combined_df['invoice_date'] = pd.to_datetime(combined_df['invoice_date'], format='%m/%d/%y')

# %%
# Confirm that the "invoice_date" data type has been changed.
combined_df['invoice_date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
tot = combined_df.groupby(['region', 'state', 'city'])['units_sold'].sum().reset_index()
tot = tot.rename(columns={'units_sold': 'Total_Products_Sold'}).sort_values('Total_Products_Sold', ascending=False)



# Show the top 5 results.
tot.head()
# Out:
#        region       state           city  Total_Products_Sold
# 21  Northeast    New York       New York               111954
# 33      South       Texas        Houston                90322
# 44       West  California  San Francisco                85478
# 43       West  California    Los Angeles                76384
# 34  Southeast     Florida          Miami                73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
tot = pd.pivot_table(combined_df,
                     index=['region', 'state', 'city'],
                     values='units_sold',
                     aggfunc='sum').sort_values('units_sold', ascending=False)

# Rename the "units_sold" column to "Total_Products_Sold"
tot = tot.rename(columns={'units_sold': 'Total_Products_Sold'})

# Show the top 5 results.
tot.head()
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
tot_sales = combined_df.groupby(['region', 'state', 'city'])['total_sales'].sum().reset_index()
tot_sales = tot_sales.rename(columns={'total_sales': 'Total_Sales'}).sort_values('Total_Sales', ascending=False)

# Show the top 5 results.
tot_sales.head()
# Out:
#        region           state           city  Total_Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
tot_sales = pd.pivot_table(combined_df,
                     index=['region', 'state', 'city'],
                     values='total_sales',
                     aggfunc='sum').sort_values('total_sales', ascending=False)


# Optional: Rename the "total_sales" column to "Total Sales"
tot_sales = tot_sales.rename(columns={'total_sales': 'Total_Sales'})

# Show the top 5 results.
tot_sales.head()
# Out:
#                                         Total_Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
ret_sales = combined_df.groupby(['retailer', 'region', 'state', 'city'])['total_sales'].sum().reset_index()
ret_sales = ret_sales.rename(columns={'total_sales': 'Total_Sales'}).sort_values('Total_Sales', ascending=False)
# Show the top 5 results.
ret_sales.head()
# Out:
#         retailer     region           state           city  Total_Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
ret_sales = pd.pivot_table(combined_df,
                     index=['retailer', 'region', 'state', 'city'],
                     values='total_sales',
                     aggfunc='sum').sort_values('total_sales', ascending=False)

# Optional: Rename the "total_sales" column to "Total Sales"
ret_sales = ret_sales.rename(columns={'total_sales': 'Total_Sales'})

# Show the top 5 results.
ret_sales.head()
# Out:
#                                                     Total_Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
womens_df = combined_df[combined_df['product'].str.contains("Women's", case=False)]
womens_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 14    Foot Locker      1185732       1/3/20  Northeast      New York
# 15    Foot Locker      1185732       1/3/20  Northeast      New York
# ...           ...          ...          ...        ...           ...
# 9633  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 9634  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 9635       Amazon      1185732     12/30/21  Northeast         Maine
# 9636       Amazon      1185732     12/30/21  Northeast         Maine
# 9637  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
#
#               city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
wom_tot = womens_df.groupby(['retailer', 'region', 'state', 'city'])['units_sold'].sum().reset_index()
wom_tot = wom_tot.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}).sort_values('Womens_Footwear_Units_Sold', ascending=False)
# Show the top 5 results.
wom_tot.head()
# Out:
#           retailer     region       state           city  \
# 103      West Gear       West  California  San Francisco
# 50          Kohl's       West  California    Los Angeles
# 22     Foot Locker  Northeast    New York       New York
# 69   Sports Direct      South       Texas         Dallas
# 83         Walmart      South       Texas        Houston
#
#      Womens_Footwear_Units_Sold
# 103                       39933
# 50                        35824
# 22                        34396
# 69                        33709
# 83                        32970

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
wom_tot = pd.pivot_table(womens_df,
                     index=['retailer', 'region', 'state', 'city'],
                     values='units_sold',
                     aggfunc='sum').sort_values('units_sold', ascending=False)

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold" 
wom_tot = wom_tot.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'})
# Show the top 5 results.
wom_tot.head()
# Out:
#                                                   Womens_Footwear_Units_Sold
# retailer      region    state      city
# West Gear     West      California San Francisco                       39933
# Kohl's        West      California Los Angeles                         35824
# Foot Locker   Northeast New York   New York                            34396
# Sports Direct South     Texas      Dallas                              33709
# Walmart       South     Texas      Houston                             32970

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
womens_df.loc[:, 'invoice_date'] = pd.to_datetime(womens_df['invoice_date'], format='%m/%d/%y')
wom_in_data = pd.pivot_table(womens_df,
                     index='invoice_date',
                     values='total_sales',
                     aggfunc='sum')
# Optional: Rename the "total_sales" column to "Total Sales"
wom_in_data = wom_in_data.rename(columns={'total_sales': 'Total_Sales'})


# Show the table.
wom_in_data
# Out:
#               Total_Sales
# invoice_date
# 2020-01-01         216293
# 2020-01-03         420200
# 2020-01-04         615080
# 2020-01-05         141801
# 2020-01-06         524500
# ...                   ...
# 2021-12-24         190885
# 2021-12-25        1042315
# 2021-12-26         396004
# 2021-12-29         211109
# 2021-12-30         167903
#
# [537 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
daily_sales = wom_in_data.resample('D').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
daily_sales = daily_sales.sort_values('Total_Sales', ascending=False)
daily_sales.head(20)
# Out:
#               Total_Sales
# invoice_date
# 2021-07-16        5647166
# 2021-06-17        5564704
# 2021-12-16        4989931
# 2021-08-17        3713411
# 2021-07-23        3713321
# 2021-11-17        3663958
# 2021-06-24        3517766
# 2021-12-09        3178767
# 2021-07-09        3135310
# 2021-06-10        2951523
# 2020-04-24        2873383
# 2021-12-23        2870633
# 2021-05-18        2828311
# 2021-08-10        2766320
# 2021-01-17        2705799
# 2021-09-05        2545592
# 2021-11-10        2530652
# 2021-06-04        2437746
# 2021-10-17        2356962
# 2021-04-17        2258868

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
weekly_sales = wom_in_data.resample('W').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
weekly_sales = weekly_sales.sort_values('Total_Sales', ascending=False)
weekly_sales.head(20)
# Out:
#               Total_Sales
# invoice_date
# 2021-07-11       12023726
# 2021-12-19       11205116
# 2021-07-18       11075465
# 2021-12-12       10549758
# 2021-06-13        9983486
# 2021-08-15        9571799
# 2021-08-22        9466033
# 2021-06-20        9445823
# 2021-11-14        9137384
# 2021-05-16        9055194
# 2021-11-21        8900453
# 2021-07-25        8871058
# 2021-06-27        8530999
# 2021-01-17        8371893
# 2021-10-17        8079938
# 2021-09-19        7703505
# 2021-10-10        7683199
# 2021-05-23        7452335
# 2021-05-09        7334738
# 2021-04-18        7123696
